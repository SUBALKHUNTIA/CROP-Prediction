# %%
# import necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# import raw data
df = pd.read_csv('cpdata.csv')

# %%
df.head()
# Out:
#    temperature   humidity        ph    rainfall label
# 0    20.879744  82.002744  6.502985  202.935536  rice
# 1    21.770462  80.319644  7.038096  226.655537  rice
# 2    23.004459  82.320763  7.840207  263.964248  rice
# 3    26.491096  80.158363  6.980401  242.864034  rice
# 4    20.130175  81.604873  7.628473  262.717340  rice

# %%
df['label'].unique()
# Out:
# array(['rice', 'wheat', 'Mung Bean', 'Tea', 'millet', 'maize', 'Lentil',
#        'Jute', 'Coffee', 'Cotton', 'Ground Nut', 'Peas', 'Rubber',
#        'Sugarcane', 'Tobacco', 'Kidney Beans', 'Moth Beans', 'Coconut',
#        'Black gram', 'Adzuki Beans', 'Pigeon Peas', 'Chickpea', 'banana',
#        'grapes', 'apple', 'mango', 'muskmelon', 'orange', 'papaya',
#        'pomegranate', 'watermelon'], dtype=object)

# %%
df.label.value_counts()
# Out:
# orange          100
# Tobacco         100
# Tea             100
# Pigeon Peas     100
# muskmelon       100
# Rubber          100
# papaya          100
# Mung Bean       100
# Sugarcane       100
# Chickpea        100
# apple           100
# Moth Beans      100
# mango           100
# rice            100
# Ground Nut      100
# maize           100
# Lentil          100
# Peas            100
# Jute            100
# wheat           100
# grapes          100
# Cotton          100
# Coconut         100
# Kidney Beans    100
# Coffee          100
# Black gram      100
# watermelon      100
# banana          100
# pomegranate     100
# Adzuki Beans    100
# millet          100
# Name: label, dtype: int64

# %%
df.shape
# Out:
# (3100, 5)

# %%
df.isna().sum()
# Out:
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %%
df.describe()
# Out:
#        temperature     humidity           ph     rainfall
# count  3100.000000  3100.000000  3100.000000  3100.000000
# mean     27.108466    66.005312     6.368913   110.213031
# std       7.566308    24.007713     0.809477    64.048562
# min       8.825675    10.034048     3.504752    20.211267
# 25%      22.810495    55.244920     5.895343    64.909095
# 50%      26.102848    68.980529     6.342518    97.057093
# 75%      29.365644    84.446524     6.841616   141.210784
# max      54.986760    99.981876     9.935091   397.315380

# %%
# data preprocessing

# %%
manual = {'label':{'rice':0, 'wheat':1, 'Mung Bean':2, 'Tea':3, 'millet':4, 'maize':5, 'Lentil':6,
       'Jute':7, 'Coffee':8, 'Cotton':9, 'Ground Nut':10, 'Peas':11, 'Rubber':12,
       'Sugarcane':13, 'Tobacco':14, 'Kidney Beans':15, 'Moth Beans':16, 'Coconut':17,
       'Black gram':18, 'Adzuki Beans':19, 'Pigeon Peas':20, 'Chickpea':21, 'banana':22,
       'grapes':23, 'apple':24, 'mango':25, 'muskmelon':26, 'orange':27, 'papaya':28,
       'pomegranate':29, 'watermelon':30}}

# %%
df.replace(manual,inplace=True)

# %%
df.tail()
# Out:
#       temperature   humidity        ph   rainfall  label
# 3095    25.287846  89.636679  6.765095  58.286977     30
# 3096    26.638386  84.695469  6.189214  48.324286     30
# 3097    25.331045  84.305338  6.904242  41.532187     30
# 3098    26.897502  83.892415  6.463271  43.971937     30
# 3099    26.986037  89.413849  6.260839  58.548767     30

# %%
# exploratory data analysis

# %%
df.columns
# Out:
# Index(['temperature', 'humidity', 'ph', 'rainfall', 'label'], dtype='object')

# %%
sns.distplot(df['temperature'])
# Out:
# C:\Users\S khuntia\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='temperature', ylabel='Density'>

# %%
sns.distplot(df['humidity'])
# Out:
# C:\Users\S khuntia\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='humidity', ylabel='Density'>

# %%
sns.distplot(df['ph'])
# Out:
# C:\Users\S khuntia\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='ph', ylabel='Density'>

# %%
sns.distplot(df['rainfall'])
# Out:
# C:\Users\S khuntia\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='rainfall', ylabel='Density'>

# %%
sns.boxplot(df['temperature'])
# Out:
# C:\Users\S khuntia\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='temperature'>

# %%
# task- find all the boxplots of independent features

# %%
# pairplot

# %%
sns.pairplot(df,hue='label')

# %%
plt.figure(figsize=(15,10))
sns.scatterplot(df.temperature,df.ph,data=df,hue='label')
# Out:
# C:\Users\S khuntia\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='temperature', ylabel='ph'>

# %%
df.columns
# Out:
# Index(['temperature', 'humidity', 'ph', 'rainfall', 'label'], dtype='object')

# %%
# splitting of independent and dependent features
X = df[['temperature', 'humidity', 'ph', 'rainfall']]
y = df['label']

# %%
# train test split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=34)

# %%
# model implementation

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()

# %%
# training of data
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([18, 10,  2, 28, 10, 29, 10,  6,  7, 22, 23, 19, 18, 25, 10, 20,  7,
#        27, 20, 21,  1, 19, 11, 29, 22, 22, 17, 22, 16, 25, 28, 15, 18,  8,
#         9, 13,  0,  2, 23, 25, 28, 24, 13, 29, 22, 23, 30, 17, 25,  7, 12,
#         6, 18,  8, 22, 17,  7, 19, 20, 14,  1,  5,  4,  7, 21, 16, 13, 27,
#         9,  5, 28,  5, 27, 18, 30,  8,  7, 14,  1, 19, 26, 25,  2,  7, 21,
#         3, 16,  7, 11, 10, 15,  2,  2, 23, 19, 11, 24,  5,  1, 17, 11, 14,
#        25, 26, 12, 15, 13,  0, 30,  6, 16, 27,  3, 29,  5,  4, 17,  1,  5,
#        25, 13, 19, 23, 14,  1,  6, 25, 13, 30, 30, 25, 12, 30,  7, 22, 16,
#        30,  5, 29,  5, 22, 10,  5, 12,  4,  4, 28, 20, 19, 23, 13,  0,  6,
#        26, 21,  5,  1, 26, 29,  7, 23, 29, 29, 30, 19, 13, 13, 27, 18,  3,
#        22, 27,  6,  9, 13, 29, 20, 19,  2,  9,  4,  3,  0, 17,  9, 14, 25,
#        23, 28, 11, 25,  7, 14, 12, 25,  3,  4, 14,  7, 23, 15,  1,  2, 16,
# ...

# %%
y_test
# Out:
# 1824    18
# 1066    10
# 228      2
# 2824    28
# 1098    10
#         ..
# 2493    24
# 1894    18
# 2001    20
# 2588    25
# 1587    15
# Name: label, Length: 775, dtype: int64

# %%
# model evaluation
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)*100
# Out:
# 92.38709677419354

# %%
# serialization of our model
from sklearn import externals
import joblib
joblib.dump('crop.pkl',model)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-f17598178e0b> in <module>
#       2 from sklearn import externals
#       3 import joblib
# ----> 4 joblib.dump('crop.pkl',model)
#
# ~\anaconda3\lib\site-packages\joblib\numpy_pickle.py in dump(value, filename, compress, protocol, cache_size)
#     443         # People keep inverting arguments, and the resulting error is
#     444         # incomprehensible
# --> 445         raise ValueError(
#     446             'Second argument should be a filename or a file-like object, '
#     447             '%s (type %s) was given.'
#
# ValueError: Second argument should be a filename or a file-like object, DecisionTreeClassifier() (type <class 'sklearn.tree._classes.DecisionTreeClassifier'>) was given.
